# %% [markdown]
# <a href="https://colab.research.google.com/github/yusleylabrador/ProyectoCiencia/blob/main/MG7Y8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import gdown

URL = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vS-dbcG9-1eHtwxzrVYhSGDdfFXXtj1o6Mu_8fyuar97S_bc_GcUv-eqX3-ieN3Zw/pub?output=csv'
df = pd.read_csv(URL)
print (df)
# Out:
#         Main Group Articulo NR Main Group Articulo DESC  Grupo Articulo NR  \
# 0                            6          ALMACEN BASICOS                 58
# 1                            6          ALMACEN BASICOS                 58
# 2                            6          ALMACEN BASICOS                 58
# 3                            6          ALMACEN BASICOS                 58
# 4                            6          ALMACEN BASICOS                 58
# ...                        ...                      ...                ...
# 483390                       8       ALMACEN EN GENERAL                 56
# 483391                       8       ALMACEN EN GENERAL                 56
# 483392                       8       ALMACEN EN GENERAL                 56
# 483393                       8       ALMACEN EN GENERAL                 56
# 483394                       8       ALMACEN EN GENERAL                 56
#
# ...

# %%
print(df.head())
# Out:
#    Main Group Articulo NR Main Group Articulo DESC  Grupo Articulo NR  \
# 0                       6          ALMACEN BASICOS                 58
# 1                       6          ALMACEN BASICOS                 58
# 2                       6          ALMACEN BASICOS                 58
# 3                       6          ALMACEN BASICOS                 58
# 4                       6          ALMACEN BASICOS                 58
#
#   Grupo Articulo DESC  Articulo NR                  Articulo DESC  Tienda NR  \
# 0         CONDIMENTOS       434135  SALSA INGLESA VANOLI BTX950ML          4
# 1         CONDIMENTOS       434135  SALSA INGLESA VANOLI BTX950ML          4
# 2         CONDIMENTOS       434135  SALSA INGLESA VANOLI BTX950ML          5
# 3         CONDIMENTOS       434135  SALSA INGLESA VANOLI BTX950ML         11
# 4         CONDIMENTOS       434135  SALSA INGLESA VANOLI BTX950ML         11
#
#   Tienda SHORT NAME  Mes ID Venta Venta Promedio Costo Venta  Ctd Vendida  \
# ...

# %%
df.shape
# Out:
# (483395, 15)

# %%
df.describe()
# Out:
#        Main Group Articulo NR  Grupo Articulo NR   Articulo NR      Tienda NR  \
# count           483395.000000      483395.000000  4.833950e+05  483395.000000
# mean                 7.311048          46.002104  1.370176e+06      15.861165
# std                  0.462981           6.968490  5.195602e+05      14.805722
# min                  6.000000          19.000000  4.940000e+02       1.000000
# 25%                  7.000000          41.000000  1.120379e+06       8.000000
# 50%                  7.000000          50.000000  1.647711e+06      14.000000
# 75%                  8.000000          51.000000  1.722864e+06      20.000000
# max                  8.000000          63.000000  1.799655e+06      80.000000
#
#               Mes ID    Ctd Vendida     Dias Stock
# count  483395.000000  357781.000000  323931.000000
# mean   202405.151398      72.757772     105.022786
# std         2.545166     128.974086     159.322699
# min    202401.000000     -42.000000    -800.000000
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Renombramos las columnas
nombres_columnas = {0: "Main_Group_NR",
                    1: "Descripción_MG",
                    2: "Grupo_Articulo_NR",
                    3:"Descripción_Grupo_Art",
                    4:"Cod_Art",
                    5:"Descripción_Art",
                    6:"Nro_Tienda",
                    7:"Descripcion_Tienda",
                    8:"Mes",
                    9: "Venta",
                    10: "Venta_Promedio",
                    11: "Costo_de_Venta",
                    12: "Cantidad_Vendida",
                    13: "Nivel_de_Servicio",
                    14: "Dias_de_Stock"}

# %%
df = df.rename(columns = nombres_columnas)
print(df)
# Out:
#         Main Group Articulo NR Main Group Articulo DESC  Grupo Articulo NR  \
# 0                            6          ALMACEN BASICOS                 58
# 1                            6          ALMACEN BASICOS                 58
# 2                            6          ALMACEN BASICOS                 58
# 3                            6          ALMACEN BASICOS                 58
# 4                            6          ALMACEN BASICOS                 58
# ...                        ...                      ...                ...
# 483390                       8       ALMACEN EN GENERAL                 56
# 483391                       8       ALMACEN EN GENERAL                 56
# 483392                       8       ALMACEN EN GENERAL                 56
# 483393                       8       ALMACEN EN GENERAL                 56
# 483394                       8       ALMACEN EN GENERAL                 56
#
# ...

# %% [markdown]
# Explorando Nulos

# %%
# Usando el método info() para resumir el dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 483395 entries, 0 to 483394
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Main Group Articulo NR    483395 non-null  int64
#  1   Main Group Articulo DESC  483395 non-null  object
#  2   Grupo Articulo NR         483395 non-null  int64
#  3   Grupo Articulo DESC       483395 non-null  object
#  4   Articulo NR               483395 non-null  int64
#  5   Articulo DESC             483395 non-null  object
#  6   Tienda NR                 483395 non-null  int64
#  7   Tienda SHORT NAME         483395 non-null  object
#  8   Mes ID                    483395 non-null  int64
#  9   Venta                     357781 non-null  object
#  10  Venta Promedio            481480 non-null  object
#  11  Costo Venta               357781 non-null  object
#  12  Ctd Vendida               357781 non-null  float64
# ...

# %%
# Convertimos el Tipo de Dato en Columnas correspondientes a Texto
df[['Main Group Articulo DESC', 'Grupo Articulo DESC','Articulo DESC','Tienda SHORT NAME', ]] = df[['Main Group Articulo DESC', 'Grupo Articulo DESC','Articulo DESC','Tienda SHORT NAME']].astype(str)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 483395 entries, 0 to 483394
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Main Group Articulo NR    483395 non-null  int64
#  1   Main Group Articulo DESC  483395 non-null  object
#  2   Grupo Articulo NR         483395 non-null  int64
#  3   Grupo Articulo DESC       483395 non-null  object
#  4   Articulo NR               483395 non-null  int64
#  5   Articulo DESC             483395 non-null  object
#  6   Tienda NR                 483395 non-null  int64
#  7   Tienda SHORT NAME         483395 non-null  object
#  8   Mes ID                    483395 non-null  int64
#  9   Venta                     357781 non-null  object
#  10  Venta Promedio            481480 non-null  object
#  11  Costo Venta               357781 non-null  object
#  12  Ctd Vendida               357781 non-null  float64
# ...

# %%
# Vemos donde estan los Nulos
print('Detalle de Nulos Por Campo:')
print(df.isnull().sum())
